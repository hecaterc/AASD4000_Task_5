# %% [markdown]
# # Task: Covid-19 Data Analysis
# ### This notebook is used to understand the comprehension of Data Analysis techniques using Pandas library.

# %% [markdown]
# ### Data Source:
# https://github.com/CSSEGISandData/COVID-19/tree/master/csse_covid_19_data/csse_covid_19_daily_reports
#
# ### File naming convention
#
# MM-DD-YYYY.csv in UTC.
#
# ### Field description
#
# - Province_State: China - province name; US/Canada/Australia/ - city name, state/province name; Others - name of the event (e.g., "Diamond Princess" cruise ship); other countries - blank.
#
# - Country_Region: country/region name conforming to WHO (will be updated).
#
# - Last_Update: MM/DD/YYYY HH:mm (24 hour format, in UTC).
#
# - Confirmed: the number of confirmed cases. For Hubei Province: from Feb 13 (GMT +8), we report both clinically diagnosed and lab-confirmed cases. For lab-confirmed cases only (Before Feb 17), please refer to who_covid_19_situation_reports. For Italy, diagnosis standard might be changed since Feb 27 to "slow the growth of new case numbers." (Source)
#
# - Deaths: the number of deaths.
#
# - Recovered: the number of recovered cases.

# %% [markdown]
# ### Question 1

# %% [markdown]
# #### Read the dataset

# %%
import pandas as pd
data = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/07-01-2020.csv')
data
# Out:
#          FIPS     Admin2    Province_State  Country_Region  \
# 0     45001.0  Abbeville    South Carolina              US
# 1     22001.0     Acadia         Louisiana              US
# 2     51001.0   Accomack          Virginia              US
# 3     16001.0        Ada             Idaho              US
# 4     19001.0      Adair              Iowa              US
# ...       ...        ...               ...             ...
# 3821      NaN        NaN           Unknown         Ukraine
# 3822      NaN        NaN               NaN           Nauru
# 3823      NaN        NaN              Niue     New Zealand
# 3824      NaN        NaN               NaN          Tuvalu
# 3825      NaN        NaN  Pitcairn Islands  United Kingdom
#
#               Last_Update        Lat       Long_  Confirmed  Deaths  \
# 0     2020-07-02 04:33:46  34.223334  -82.461707        113       0
# 1     2020-07-02 04:33:46  30.295065  -92.414197        919      37
# ...

# %% [markdown]
# #### Display the top 5 rows in the data

# %%
data.head()
# Out:
#       FIPS     Admin2  Province_State Country_Region          Last_Update  \
# 0  45001.0  Abbeville  South Carolina             US  2020-07-02 04:33:46
# 1  22001.0     Acadia       Louisiana             US  2020-07-02 04:33:46
# 2  51001.0   Accomack        Virginia             US  2020-07-02 04:33:46
# 3  16001.0        Ada           Idaho             US  2020-07-02 04:33:46
# 4  19001.0      Adair            Iowa             US  2020-07-02 04:33:46
#
#          Lat       Long_  Confirmed  Deaths  Recovered  Active  \
# 0  34.223334  -82.461707        113       0          0     113
# 1  30.295065  -92.414197        919      37          0     882
# 2  37.767072  -75.632346       1043      14          0    1029
# 3  43.452658 -116.241552       2288      23          0    2265
# 4  41.330756  -94.471059         15       0          0      15
#
#                     Combined_Key  Incidence_Rate  Case-Fatality_Ratio
# 0  Abbeville, South Carolina, US      460.716761             0.000000
# ...

# %% [markdown]
# #### Show the information of the dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3826 entries, 0 to 3825
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   FIPS                 3110 non-null   float64
#  1   Admin2               3114 non-null   object
#  2   Province_State       3649 non-null   object
#  3   Country_Region       3826 non-null   object
#  4   Last_Update          3826 non-null   object
#  5   Lat                  3748 non-null   float64
#  6   Long_                3748 non-null   float64
#  7   Confirmed            3826 non-null   int64
#  8   Deaths               3826 non-null   int64
#  9   Recovered            3826 non-null   int64
#  10  Active               3826 non-null   int64
#  11  Combined_Key         3826 non-null   object
#  12  Incidence_Rate       3748 non-null   float64
#  13  Case-Fatality_Ratio  3758 non-null   float64
# dtypes: float64(5), int64(4), object(5)
# memory usage: 418.6+ KB

# %% [markdown]
# #### Show the sum of missing values of features in the dataset

# %%
data.isnull().sum()
# Out:
# FIPS                   716
# Admin2                 712
# Province_State         177
# Country_Region           0
# Last_Update              0
# Lat                     78
# Long_                   78
# Confirmed                0
# Deaths                   0
# Recovered                0
# Active                   0
# Combined_Key             0
# Incidence_Rate          78
# Case-Fatality_Ratio     68
# dtype: int64

# %% [markdown]
# ### Question 2

# %% [markdown]
# #### Show the number of Confirmed cases by Country

# %%
data.groupby('Country_Region', as_index=False)['Confirmed'].sum()
# Out:
#            Country_Region  Confirmed
# 0             Afghanistan      31848
# 1                 Albania       2580
# 2                 Algeria      14272
# 3                 Andorra        855
# 4                  Angola        291
# ..                    ...        ...
# 192    West Bank and Gaza       2758
# 193  Winter Olympics 2022          0
# 194                 Yemen       1190
# 195                Zambia       1632
# 196              Zimbabwe        605
#
# [197 rows x 2 columns]

# %% [markdown]
# #### Show the number of Deaths by Country

# %%
data.groupby('Country_Region', as_index=False)['Deaths'].sum()
# Out:
#            Country_Region  Deaths
# 0             Afghanistan     778
# 1                 Albania      65
# 2                 Algeria     920
# 3                 Andorra      52
# 4                  Angola      15
# ..                    ...     ...
# 192    West Bank and Gaza       8
# 193  Winter Olympics 2022       0
# 194                 Yemen     318
# 195                Zambia      30
# 196              Zimbabwe       7
#
# [197 rows x 2 columns]

# %% [markdown]
# #### Show the number of Recovered cases by Country

# %%
data.groupby('Country_Region', as_index=False)['Recovered'].sum()
# Out:
#            Country_Region  Recovered
# 0             Afghanistan      15651
# 1                 Albania       1516
# 2                 Algeria      10040
# 3                 Andorra        799
# 4                  Angola         97
# ..                    ...        ...
# 192    West Bank and Gaza        460
# 193  Winter Olympics 2022          0
# 194                 Yemen        504
# 195                Zambia       1348
# 196              Zimbabwe        166
#
# [197 rows x 2 columns]

# %% [markdown]
# #### Show the number of Active Cases by Country

# %%
data.groupby('Country_Region', as_index=False)['Active'].sum()
# Out:
#            Country_Region  Active
# 0             Afghanistan   15419
# 1                 Albania     999
# 2                 Algeria    3312
# 3                 Andorra       4
# 4                  Angola     179
# ..                    ...     ...
# 192    West Bank and Gaza    2290
# 193  Winter Olympics 2022       0
# 194                 Yemen     368
# 195                Zambia     254
# 196              Zimbabwe     432
#
# [197 rows x 2 columns]

# %% [markdown]
# #### Show the latest number of Confirmed, Deaths, Recovered and Active cases Country-wise

# %%
data.groupby('Country_Region', as_index=False)[['Confirmed', 'Deaths', 'Recovered', 'Active']].sum()
# Out:
#            Country_Region  Confirmed  Deaths  Recovered  Active
# 0             Afghanistan      31848     778      15651   15419
# 1                 Albania       2580      65       1516     999
# 2                 Algeria      14272     920      10040    3312
# 3                 Andorra        855      52        799       4
# 4                  Angola        291      15         97     179
# ..                    ...        ...     ...        ...     ...
# 192    West Bank and Gaza       2758       8        460    2290
# 193  Winter Olympics 2022          0       0          0       0
# 194                 Yemen       1190     318        504     368
# 195                Zambia       1632      30       1348     254
# 196              Zimbabwe        605       7        166     432
#
# [197 rows x 5 columns]

# %% [markdown]
# ### Question 3

# %% [markdown]
# ### Show the countries with no recovered cases

# %%
x = data.groupby('Country_Region', as_index=False).filter(lambda x:x['Recovered'].sum() == 0)
x.groupby('Country_Region', as_index=False)['Recovered'].sum()
# Out:
#           Country_Region  Recovered
# 0             Antarctica          0
# 1               Kiribati          0
# 2           Korea, North          0
# 3             MS Zaandam          0
# 4                  Nauru          0
# 5                  Palau          0
# 6                  Samoa          0
# 7   Summer Olympics 2020          0
# 8                 Sweden          0
# 9                  Tonga          0
# 10                Tuvalu          0
# 11  Winter Olympics 2022          0

# %% [markdown]
# #### Show the countries with no confirmed cases

# %%
y = data.groupby('Country_Region', as_index=False).filter(lambda x:x['Confirmed'].sum() == 0)
y.groupby('Country_Region', as_index=False)['Confirmed'].sum()
# Out:
#          Country_Region  Confirmed
# 0            Antarctica          0
# 1              Kiribati          0
# 2          Korea, North          0
# 3                 Nauru          0
# 4                 Palau          0
# 5                 Samoa          0
# 6  Summer Olympics 2020          0
# 7                 Tonga          0
# 8                Tuvalu          0
# 9  Winter Olympics 2022          0

# %% [markdown]
# #### Show the countries with no deaths

# %%
z = data.groupby('Country_Region', as_index=False).filter(lambda x:x['Deaths'].sum() == 0)
z.groupby('Country_Region', as_index=False)['Deaths'].sum()
# Out:
#                       Country_Region  Deaths
# 0                         Antarctica       0
# 1                             Bhutan       0
# 2                           Cambodia       0
# 3                           Dominica       0
# 4                            Eritrea       0
# 5                               Fiji       0
# 6                            Grenada       0
# 7                           Holy See       0
# 8                           Kiribati       0
# 9                       Korea, North       0
# 10                              Laos       0
# 11                           Lesotho       0
# 12                          Mongolia       0
# 13                           Namibia       0
# 14                             Nauru       0
# 15                             Palau       0
# 16                  Papua New Guinea       0
# 17             Saint Kitts and Nevis       0
# 18                       Saint Lucia       0
# 19  Saint Vincent and the Grenadines       0
# ...

# %% [markdown]
# ### Question 4

# %% [markdown]
# #### Show the Top 10 countries with Confirmed cases

# %%
data.groupby('Country_Region', as_index=False)['Confirmed'].sum().nlargest(10, 'Confirmed')
# Out:
#      Country_Region  Confirmed
# 183              US    2702432
# 24           Brazil    1459494
# 145          Russia     653479
# 80            India     604641
# 187  United Kingdom     314989
# 139            Peru     288477
# 36            Chile     282043
# 164           Spain     249659
# 86            Italy     240760
# 116          Mexico     231770

# %% [markdown]
# #### Show the Top 10 Countries with Active cases

# %%
data.groupby('Country_Region', as_index=False)['Active'].sum().nlargest(10, 'Active')
# Out:
#      Country_Region   Active
# 183              US  2570899
# 24           Brazil   462273
# 187  United Kingdom   269629
# 139            Peru   250028
# 80            India   226947
# 145          Russia   221723
# 134        Pakistan   108642
# 63           France    98695
# 14       Bangladesh    85262
# 162    South Africa    80559

# %% [markdown]
# ### Question 5

# %% [markdown]
# #### Plot Country-wise Total deaths, confirmed, recovered and active casaes where total deaths have exceeded 50,000

# %%
import matplotlib.pyplot as plt

# %%
plot1 = data.groupby('Country_Region').filter(lambda x:x['Deaths'].sum() > 50000)
plot1 = plot1.groupby('Country_Region')[['Confirmed', 'Deaths', 'Recovered', 'Active']].sum()
plot1.plot()
plt.xlabel('')
plt.title('Total Deaths(>50000), Confirmed, Recovered, and Active Cases by Country')
plot1
# Out:
#                 Confirmed  Deaths  Recovered   Active
# Country_Region
# Brazil            1459494   60878     926192   462273
# US                2702432  127746     729994  2570899
# United Kingdom     314989   56338       1372   269629

# %% [markdown]
# ### Question 6

# %% [markdown]
# ### Plot Province/State wise Deaths in USA

# %%
import plotly.express as px

# %%
covid_data= pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/01-09-2021.csv')

# %%
covid_data.columns
# Out:
# Index(['FIPS', 'Admin2', 'Province_State', 'Country_Region', 'Last_Update',
#        'Lat', 'Long_', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'Combined_Key', 'Incident_Rate', 'Case_Fatality_Ratio'],
#       dtype='object')

# %%
fig = px.bar(covid_data[covid_data['Country_Region'] == 'US'], x='Province_State', y='Deaths', title='Province/State-wise Deaths in USA')
fig.show()
# Out:
# <div>                            <div id="924d8292-6a22-4e15-9b6f-3519028093a6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("924d8292-6a22-4e15-9b6f-3519028093a6")) {                    Plotly.newPlot(                        "924d8292-6a22-4e15-9b6f-3519028093a6",                        [{"alignmentgroup":"True","hovertemplate":"Province_State=%{x}<br>Deaths=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Ala
# ...

# %% [markdown]
# ### Question 7

# %% [markdown]
# ### Plot Province/State Wise Active Cases in USA

# %%
fig = px.bar(covid_data[covid_data['Country_Region'] == 'US'], x='Province_State', y='Active', title='Province/State-wise Active Cases in USA')
fig.show()
# Out:
# <div>                            <div id="e81262be-acbf-41f2-b371-441ac35e84bb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e81262be-acbf-41f2-b371-441ac35e84bb")) {                    Plotly.newPlot(                        "e81262be-acbf-41f2-b371-441ac35e84bb",                        [{"alignmentgroup":"True","hovertemplate":"Province_State=%{x}<br>Active=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Ala
# ...

# %% [markdown]
# ### Question 8

# %% [markdown]
# ### Plot Province/State Wise Confirmed cases in USA

# %%
fig = px.bar(covid_data[covid_data['Country_Region'] == 'US'], x='Province_State', y='Confirmed', title='Province/State-wise Confirmed Cases in USA')
fig.show()
# Out:
# <div>                            <div id="6a660ed7-f838-4c6d-9027-595e0fb67395" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6a660ed7-f838-4c6d-9027-595e0fb67395")) {                    Plotly.newPlot(                        "6a660ed7-f838-4c6d-9027-595e0fb67395",                        [{"alignmentgroup":"True","hovertemplate":"Province_State=%{x}<br>Confirmed=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","Alabama","
# ...

# %% [markdown]
# ### Question 9

# %% [markdown]
# ### Plot Worldwide Confirmed Cases over time

# %%
import plotly.express as px
import plotly.io as pio

# %%
# not sure why the graph looks wierd. Maybe i missed something
covid_data['Last_Update'] = pd.to_datetime(covid_data['Last_Update'])
fig = px.line(covid_data, x='Last_Update', y='Confirmed', title='Worldwide Confirmed Cases Over Time')
pio.show(fig)
# Out:
# <div>                            <div id="d0fe7b67-cc93-40f1-a81f-08ed53c00056" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d0fe7b67-cc93-40f1-a81f-08ed53c00056")) {                    Plotly.newPlot(                        "d0fe7b67-cc93-40f1-a81f-08ed53c00056",                        [{"hovertemplate":"Last_Update=%{x}<br>Confirmed=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2021-01-10T05:22:12","2021-01-10T05:22:12","2021-01-10T05:22:12","2021-01-10T05:22:12","2021-01-10T05:22:12","2021-01-10T05:22:12","2021-01-10T05:22:12","2021-01-10T05:22:12","2021-01-10T05:22:12","2021-01-10T05:22:12","2021-01-10T05:22:12","2021-01-10T05:22:1
# ...
